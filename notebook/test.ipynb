# %% [markdown]
# ### Create interference for LLM

# %%
from langgraph.graph import StateGraph, MessagesState
from langgraph.constants import START, END
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.store.memory import InMemoryStore
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_ollama import ChatOllama

    
from dotenv import load_dotenv
import os

# ---------------- Load env ----------------
load_dotenv()

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

checkpoint = InMemorySaver()
store = InMemoryStore()

# ---------------- Models ----------------
gemini_model = ChatGoogleGenerativeAI(
    model="models/gemini-2.5-flash", api_key=GEMINI_API_KEY
)
ollama_model = ChatOllama(model="gemma3n", disable_streaming=False)

# fallback: if Gemini fails, use Ollama
model = gemini_model.with_fallbacks([ollama_model])

def call_model(state: MessagesState):
    response = model.invoke(state["messages"])
    state["messages"].append(response)
    return state


def create_state_graph():
    """
    Creates and returns a state graph with predefined nodes, edges, and memory checkpointing.

    Returns:
        StateGraph: A compiled state graph with nodes and edges set up.
    """

    workflow = (
        StateGraph(MessagesState)
        .add_node("call_model", call_model)
        .add_edge(START, "call_model")
        .add_edge("call_model", END)
        .compile(checkpointer=checkpoint, store=store)
    )

    return workflow

# Create the state graph
resume_agent = create_state_graph()

# %%
config = {
    "configurable":{
        "thread_id": "2"
    }
}

# %%
for chunk, metadata in resume_agent.stream({"messages":"what is space? explain in long asnwer"}, stream_mode="messages", config=config):
    if chunk.content:
        print(chunk.content, end="\n\n")
# Out:
# Space is one of the most fundamental and profound concepts in physics and philosophy, yet its precise nature remains a subject of ongoing inquiry and debate. Far more than just the "empty" region between objects, our understanding of space has evolved dramatically from
#
#  ancient philosophical ideas to the complex, dynamic entity described by modern physics.
#
# Here's a long explanation of what space is:
#
# ---
#
# ### The Intuitive and Everyday Understanding
#
# At its most basic, intuitive level, **space is
#
#  the three-dimensional extent in which objects and events have relative position and direction.** It's the "where" of everything. When we say something is "here" or "there," "up" or "down," "left"
#
#  or "right," we are referring to its position in space. It's the container that holds the universe, allowing for movement, separation, and the arrangement of matter. We perceive it as having three dimensions: length, width, and height
#
# , which allow us to define the volume of objects and the distances between them.
#
# ### Historical and Philosophical Perspectives
#
# The concept of space has been a cornerstone of philosophical and scientific thought for millennia:
#
# 1.  **Ancient Views (e.g
#
# ., Aristotle):** For Aristotle, space was not an empty void but rather a collection of "places." Every object had a natural place, and motion was the process of seeking that place. There was no concept of an absolute, infinite empty
#
#  space.
#
# 2.  **Newton's Absolute Space:** Isaac Newton, in his *Principia Mathematica*, proposed the idea of **absolute space**. For Newton, space was a fundamental, infinite, immutable, and independent entity, existing whether
#
#  anything was in it or not. It was like an invisible, unchanging stage upon which all physical events unfolded, unaffected by the presence or absence of matter. It provided a fixed reference frame against which all motion could be measured. He famously called it "
#
# God's sensorium."
#
# 3.  **Leibniz's Relational Space:** Gottfried Wilhelm Leibniz challenged Newton's absolute space, arguing for a **relational view**. For Leibniz, space was not an independent entity
#
#  but merely a system of relations between objects. If there were no objects, there would be no space. Space was an abstraction derived from the positions and distances of things. This view emphasized that only relative motion (the motion of objects with respect to each other
#
# ) was physically meaningful.
#
# ### Modern Scientific Understanding: Spacetime
#
# The most revolutionary shift in our understanding of space came with Albert Einstein's theories of relativity:
#
# 1.  **Special Relativity (1905):**
#
#  Einstein showed that space and time are not independent but are inextricably linked into a single, four-dimensional continuum called **spacetime**. In special relativity, the measurements of space and time intervals between events are relative to the observer's motion. There
#
#  is no absolute, universal "now" or absolute distance; these depend on the observer's frame of reference. This means that concepts like "length contraction" and "time dilation" occur as objects approach the speed of light.
#
# 2.
#
# **General Relativity (1915):** This is where space truly becomes dynamic. Einstein demonstrated that **spacetime is not merely a passive backdrop but an active participant in the universe's dynamics.** Mass and energy "warp" or "curve
#
# " spacetime, and this curvature is what we perceive as gravity. Objects (like planets, stars, light) do not feel a "force" pulling them; instead, they follow the shortest path (geodesic) through the curved spacetime created
#
#  by other massive objects.
#     *   **No longer a static container:** Spacetime is a flexible, deformable "fabric" that can be stretched, compressed, and bent.
#     *   **Gravity as geometry:** Gravity is no
#
#  longer a force acting *in* space, but a manifestation of the geometry *of* spacetime itself.
#
# ### Key Characteristics and Properties of Space (as Spacetime)
#
# Based on modern physics, space (as part of spacetime)
#
#  has several crucial characteristics:
#
# 1.  **Dimensionality:** We experience three spatial dimensions (up/down, left/right, forward/backward). In string theory and other advanced models, there might be additional, compactified (cur
#
# led-up) dimensions, but these are not directly observable at our scale.
#
# 2.  **Curvature:** As described by general relativity, spacetime is curved by the presence of mass and energy. This curvature dictates the paths of objects and
#
#  light.
#
# 3.  **Expansion:** Cosmology has revealed that space itself is expanding. The universe is not merely expanding *into* pre-existing space; rather, the "fabric" of space itself is stretching, carrying galaxies further apart. This
#
#  expansion started with the Big Bang and is currently accelerating due to a mysterious force called **dark energy**.
#
# 4.  **Not Truly Empty (The Quantum Vacuum):** Even in the deepest vacuum of space, it's not truly empty. According to
#
#  quantum field theory, the vacuum is a bustling arena of "virtual particles" constantly popping in and out of existence, fluctuations in quantum fields, and the presence of fundamental fields (like the Higgs field).
#
# 5.  **Homogeneity and Isot
#
# ropy (on large scales):** On the largest scales, the universe appears to be roughly homogeneous (the same everywhere) and isotropic (the same in all directions). This is known as the Cosmological Principle and is a cornerstone of modern cosmology.
#
# 6
#
# .  **Dynamic and Evolving:** Space is not fixed or immutable. It expands, it curves, and its properties are intrinsically linked to the distribution and movement of matter and energy within it.
#
# ### Philosophical Implications and Unanswered Questions
#
# Despite
#
#  our advanced understanding, space still poses deep philosophical questions:
#
# *   **Is space fundamental or emergent?** Is it a basic component of reality, or does it emerge from more fundamental entities (like quantum entanglement or a network of relationships)?
# *
#
# **Is space truly continuous or discrete?** At the Planck scale (the smallest theoretical unit of length), some theories of quantum gravity suggest that spacetime might have a granular, pixelated structure rather than being perfectly smooth.
# *   **Is space
#
#  finite or infinite?** While the observable universe has a finite size, the universe as a whole might be infinite, or it might be finite but unbounded (like the surface of a sphere, which has a finite area but no edge).
# *
#
# **What is the "edge" of the universe (if any)?** If space is expanding, does it expand into something, or is it simply creating more space?
#
# ### Conclusion
#
# In conclusion, space is far more than just "
#
# nothingness" or a passive container. It is an active, dynamic, and fundamental component of reality, inextricably interwoven with time to form spacetime. Its geometry dictates gravity, its expansion drives the evolution of the universe, and its properties are intimately
#
#  linked to the matter and energy within it. From Newton's absolute stage to Einstein's curved fabric and the quantum foam of modern theory, our understanding of space continues to evolve, pushing the boundaries of human knowledge and revealing the profound interconnected
#
# ness of the cosmos.

# %% [markdown]
# ### Extract Text from Pdf

# %%
from pypdf import PdfReader

def extract_text_from_pdf(file_path: str) -> str:
    """
    Extracts text from a PDF file.
    
    Args:
        file_path (str): Path to the PDF file.
        
    Returns:
        str: Extracted text from all pages.
    """
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() or ""  # Some pages may return None
        text += "\n"
    return text.strip()

# %%
pdf_file = r"C:\Users\jigne\Downloads\190210107071_Resume.pdf"
resume_text = extract_text_from_pdf(pdf_file)

# %%
SYSTEM_PROMPT = """
You are a resume information extraction agent.  
Your task is to extract structured information from resumes.  

name: full name of the candidate
email: email address
phone: phone number
education: list of education entries, each with degree, institution, start_date, end_date,
grade (if available)
projects: list of projects, each with project_name, description, technologies (list of technologies used),
link (if available)
experience: list of work experience entries, each with job_title, company, location,
start_date, end_date, responsibilities (list of responsibilities/achievements)
skills: list of skills
other_info: dictionary with optional fields:
  certifications: list of certifications (if available)
  languages: list of languages (if available)
  achievements: list of achievements (if available)
  links: dictionary with optional fields linkedin, github, portfolio (if available)

Rules:
- Do not hallucinate. If information is not present, return null or empty list.
- Always return JSON only, with no extra text.
- Keep field values concise but complete.
"""

# %%
from pydantic import BaseModel, Field
from typing import List, Optional


class EducationEntry(BaseModel):
    degree: Optional[str] = ""
    institution: Optional[str] = ""
    start_date: Optional[str] = ""
    end_date: Optional[str] = ""
    grade: Optional[str] = ""


class ProjectEntry(BaseModel):
    project_name: Optional[str] = ""
    description: Optional[str] = ""
    technologies: List[str] = Field(default_factory=list)
    link: Optional[str] = ""


class ExperienceEntry(BaseModel):
    job_title: Optional[str] = ""
    company: Optional[str] = ""
    location: Optional[str] = ""
    start_date: Optional[str] = ""
    end_date: Optional[str] = ""
    responsibilities: List[str] = Field(default_factory=list)


class Links(BaseModel):
    linkedin: Optional[str] = ""
    github: Optional[str] = ""
    portfolio: Optional[str] = ""


class OtherInfo(BaseModel):
    certifications: List[str] = Field(default_factory=list)
    languages: List[str] = Field(default_factory=list)
    achievements: List[str] = Field(default_factory=list)
    links: Links = Field(default_factory=Links)


class ResumeExtractionData(BaseModel):
    name: Optional[str] = ""
    email: Optional[str] = ""
    phone: Optional[str] = ""
    education: List[EducationEntry] = Field(default_factory=list)
    projects: List[ProjectEntry] = Field(default_factory=list)
    experience: List[ExperienceEntry] = Field(default_factory=list)
    skills: List[str] = Field(default_factory=list)
    other_info: OtherInfo = Field(default_factory=OtherInfo)


extraction_model = gemini_model.with_structured_output(schema=ResumeExtractionData).with_fallbacks([ollama_model])

# %%
from langchain_core.prompts import ChatPromptTemplate


prompt_template = ChatPromptTemplate.from_messages([
    (
        "system", SYSTEM_PROMPT
    ),
    ("human", "Extract all possible information from the following resume text: {text}"),
])


prompt = prompt_template.invoke({"text": resume_text})

# %%
response = extraction_model.invoke(prompt)

# %%
json_reponse_for_pass_to_llm = response.model_dump_json()

# %% [markdown]
# ### Create resume templete

# %%
TEMPLATE_PROMPT = f"""
You are a professional resume designer. 
Generate a complete HTML resume with inline CSS styling based only on the JSON data provided. 

- Input will be candidate information in JSON format.  
- Use the JSON data to fill the resume directly. Do not include placeholders.  
- Layout: single-column, ATS-friendly, no tables, no graphics.  
- Typography: Use clean fonts (Arial, Helvetica, sans-serif).  
- Styling: proper spacing, bold section headings, consistent font sizes, clear separation between sections.  
- Dates: Display in format "Start Date - End Date" if available, otherwise omit.  
- Only include sections that have data in the JSON.  
- Output must be valid HTML only (no markdown, no explanations).  

This is the resume data in JSON:
{ response.model_dump }
"""

# %%
def generate_resume_template():
    response = gemini_model.invoke(TEMPLATE_PROMPT.format(data=json_reponse_for_pass_to_llm))
    return response

template_html = generate_resume_template()

# %%
from jinja2 import Template
from weasyprint import HTML

def render_resume(resume_data, template_html, output_file="resume.pdf"):
    template = Template(template_html)
    html_out = template.render(**resume_data)
    HTML(string=html_out).write_pdf(output_file)
    print(f"✅ Resume generated: {output_file}")

# %%
render_resume(response.model_dump(), template_html.content)
# Out:
# ✅ Resume generated: resume.pdf
